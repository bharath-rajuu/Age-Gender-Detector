# %% [markdown]
# # Model Notebook

# %% [markdown]
# NoteBook for our Age & Gender Detector. We will be extracting the data, train our model, fit it and then optimize is for better results.

# %% [markdown]
# ## Import the necessary libraries

# %%
import tensorflow as tf
import cv2
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.layers import Dropout, Flatten, BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Activation, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam, Adagrad, Adadelta, RMSprop

# %% [markdown]
# ## Extracting data from the dataset

# %% [markdown]
# Download the datasets from [here](https://www.kaggle.com/datasets/jangedoo/utkface-new)

# %%
filedr = "./UTKFace"

# %%
import os
files = os.listdir(filedr)

# %% [markdown]
# ## Populating list of image from the dataset

# %%
ages = []
genders = []
images = []

for fl in files:
    age = int(fl.split('_')[0])
    gender = int(fl.split('_')[1])
    filename = filedr + '/' + fl
    #print(filename)

    image = cv2.imread(filename)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (48, 48))
    images.append(image)

# %% [markdown]
# ## Populating list of Age and Gender from the dataset

# %%
for fl in files:
    age = int(fl.split('_')[0])
    gender = int(fl.split('_')[1])
    
    ages.append(age)
    genders.append(gender)

# %% [markdown]
# ## Viewing a sample from our imported dataset

# %%
plt.imshow(images[88])

# %%
print("Age: {}, Gender: {}".format(ages[88], genders[88]))
# Out:
# Age: 10, Gender: 0

# %% [markdown]
# ## Saving ages array, genders array and images array in the system

# %%
ages_f = np.array(ages)
genders_f = np.array(genders)
images_f = np.array(images)

# %%
np.save(filedr + "image.npy", images_f)
np.save(filedr + "gender.npy", genders_f)
np.save(filedr + "age.npy", ages_f)

# %% [markdown]
# ## Counting the number of males and females samples respectively

# %%
values, counts = np.unique(genders_f, return_counts = True)
print(counts)
# Out:
# [12391 11317]

# %% [markdown]
# ## Plotting the number of Male and Female samples

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
gender = ["Male", "Female"]
values = counts
ax.bar(gender, values)
plt.show()

# %% [markdown]
# ## Counting the number of samples for each age

# %%
values, counts = np.unique(ages_f, return_counts = True)
print(counts)
# Out:
# [1123  482  289  273  196  131  139  263  166  156   65  130   81  157
#   177  247  158  262   98  284  346  395  426  859  734 2197  615  918
#   570  724  350  664  143  409  880  483  293  325  266  526  132  266
#   157  100  440  153  170  153  148  381  138  232  241  353  268  236
#    97  271   82  293  161  125  103   50  259   77   94  100   56  147
#    33   98   63   32  148   58   28   69   23  133   22   40   18   24
#   155   35   10   34   33   82    2   13    5    9   17    9   11    2
#     1    5    5    1    3    4]

# %% [markdown]
# ## Converting Age counts to list

# %%
val = values.tolist()
cnt = counts.tolist()

# %% [markdown]
# ## Plotting the samples Agewise

# %%
plt.plot(counts)
plt.xlabel('Ages')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Defining Labels for output

# %%
labels = []
i = 0
while i < len(ages):
    label = []
    label.append(ages[i])
    label.append(genders[i])

    labels.append(label)
    i = i + 1

# %% [markdown]
# ## Creating simplified image list for better learning of our model

# %%
images_f_2 = images_f/255
images_f_2.shape
# Out:
# (23708, 48, 48, 3)

# %%
labels_f = np.array(labels)

# %% [markdown]
# ## Splitting dataset into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(images_f_2, labels_f, test_size=0.25)

# %%
Y_train[0:6]
# Out:
# array([[45,  0],
#        [31,  0],
#        [37,  0],
#        [24,  1],
#        [31,  0],
#        [23,  1]])

# %% [markdown]
# ## Splitting the 'Y_train' & 'Y_test' further for better analysis

# %%
Y_train_2 = [Y_train[:, 1], Y_train[:, 0]]
Y_test_2 = [Y_test[:, 1], Y_test[:, 0]]

# %%
Y_train_2[0][0:6]
# Out:
# array([0, 0, 0, 1, 0, 1])

# %%
Y_train_2[1][0:6]
# Out:
# array([45, 31, 37, 24, 31, 23])

# %% [markdown]
# ## Defining the model

# %%
def Convolution(input_tensor, filters):
    x = Conv2D(filters = filters, kernel_size = (3, 3), padding = "same", strides = (1, 1), kernel_regularizer = l2(0.001))(input_tensor)
    x = Dropout(0.1)(x)
    x = Activation('relu')(x)

    return x

# %%
def model(input_shape):
    inputs = Input((input_shape))

    ## Convolutional Layers & MaxPool Layers
    conv_1 = Convolution(inputs, 32)
    maxp_1 = MaxPooling2D(pool_size = (2, 2))(conv_1)
    conv_2 = Convolution(maxp_1, 64)
    maxp_2 = MaxPooling2D(pool_size = (2, 2))(conv_2)
    conv_3 = Convolution(maxp_2, 128)
    maxp_3 = MaxPooling2D(pool_size = (2, 2))(conv_3)
    conv_4 = Convolution(maxp_3, 256)
    maxp_4 = MaxPooling2D(pool_size = (2, 2))(conv_4)

    ## 3D matrix into 1D vector
    flatten = Flatten()(maxp_4)

    dense_1 = Dense(64, activation = 'relu')(flatten)
    dense_2 = Dense(64, activation = 'relu')(flatten)

    drop_1 = Dropout(0.2)(dense_1)
    drop_2 = Dropout(0.2)(dense_2)

    output_1 = Dense(1, activation = 'sigmoid', name = 'sex-out')(drop_1)
    output_2 = Dense(1, activation = 'relu', name = 'age-out')(drop_2)

    model = Model(inputs = [inputs], outputs = [output_1, output_2])
    model.compile(loss = ["binary_crossentropy", "mae"], optimizer = "Adam", metrics = ["accuracy"])

    return model

# %%
Model = model((48, 48, 3))

# %%
Model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 48, 48, 32)           896       ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 48, 48, 32)           0         ['conv2d[0][0]']
#
#  activation (Activation)     (None, 48, 48, 32)           0         ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 32)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)           18496     ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 24, 24, 64)           0         ['conv2d_1[0][0]']
#
#  activation_1 (Activation)   (None, 24, 24, 64)           0         ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)          73856     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 12, 12, 128)          0         ['conv2d_2[0][0]']
#
#  activation_2 (Activation)   (None, 12, 12, 128)          0         ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 128)            0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 256)            295168    ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 6, 6, 256)            0         ['conv2d_3[0][0]']
#
#  activation_3 (Activation)   (None, 6, 6, 256)            0         ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 3, 3, 256)            0         ['activation_3[0][0]']
#  g2D)
#
#  flatten (Flatten)           (None, 2304)                 0         ['max_pooling2d_3[0][0]']
#
#  dense (Dense)               (None, 64)                   147520    ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   147520    ['flatten[0][0]']
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['dense[0][0]']
#
#  dropout_5 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  sex-out (Dense)             (None, 1)                    65        ['dropout_4[0][0]']
#
#  age-out (Dense)             (None, 1)                    65        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 683586 (2.61 MB)
# Trainable params: 683586 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Initializing the Model

# %%
file_s = "Age_Sex_Detector.h5"
checkpoint = ModelCheckpoint(file_s, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
Early_stop = tf.keras.callbacks.EarlyStopping(patience = 75, monitor = 'val_loss', restore_best_weights = 'True')
callback_list = [checkpoint, Early_stop]

# %% [markdown]
# ## Running the Model
# ### Time taking process

# %%
History = Model.fit(X_train, Y_train_2, batch_size=64, validation_data=(X_test, Y_test_2), epochs=250, callbacks=callback_list)
# Out:
# Epoch 1/250
# 278/278 [==============================] - ETA: 0s - loss: 16.6119 - sex-out_loss: 0.6939 - age-out_loss: 15.7286 - sex-out_accuracy: 0.5463 - age-out_accuracy: 0.0475
# Epoch 1: val_loss improved from inf to 17.57811, saving model to Age_Sex_Detector.h5
# 278/278 [==============================] - 45s 158ms/step - loss: 16.6119 - sex-out_loss: 0.6939 - age-out_loss: 15.7286 - sex-out_accuracy: 0.5463 - age-out_accuracy: 0.0475 - val_loss: 17.5781 - val_sex-out_loss: 0.6576 - val_age-out_loss: 16.7406 - val_sex-out_accuracy: 0.5917 - val_age-out_accuracy: 0.0466
# Epoch 2/250
#   1/278 [..............................] - ETA: 36s - loss: 14.7001 - sex-out_loss: 0.6681 - age-out_loss: 13.8521 - sex-out_accuracy: 0.5781 - age-out_accuracy: 0.0000e+00
# c:\Users\bru80\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 278/278 [==============================] - ETA: 0s - loss: 13.1712 - sex-out_loss: 0.5974 - age-out_loss: 12.3591 - sex-out_accuracy: 0.6855 - age-out_accuracy: 0.0472
# Epoch 2: val_loss improved from 17.57811 to 16.00875, saving model to Age_Sex_Detector.h5
# 278/278 [==============================] - 43s 155ms/step - loss: 13.1712 - sex-out_loss: 0.5974 - age-out_loss: 12.3591 - sex-out_accuracy: 0.6855 - age-out_accuracy: 0.0472 - val_loss: 16.0088 - val_sex-out_loss: 0.5831 - val_age-out_loss: 15.1766 - val_sex-out_accuracy: 0.7176 - val_age-out_accuracy: 0.0375
# Epoch 3/250
# 278/278 [==============================] - ETA: 0s - loss: 11.0850 - sex-out_loss: 0.5155 - age-out_loss: 10.3030 - sex-out_accuracy: 0.7491 - age-out_accuracy: 0.0443
# Epoch 3: val_loss improved from 16.00875 to 13.09773, saving model to Age_Sex_Detector.h5
# 278/278 [==============================] - 43s 154ms/step - loss: 11.0850 - sex-out_loss: 0.5155 - age-out_loss: 10.3030 - sex-out_accuracy: 0.7491 - age-out_accuracy: 0.0443 - val_loss: 13.0977 - val_sex-out_loss: 0.4698 - val_age-out_loss: 12.3449 - val_sex-out_accuracy: 0.7879 - val_age-out_accuracy: 0.0462
# Epoch 4/250
# 278/278 [==============================] - ETA: 0s - loss: 10.3545 - sex-out_loss: 0.4679 - age-out_loss: 9.5904 - sex-out_accuracy: 0.7783 - age-out_accuracy: 0.0453
# Epoch 4: val_loss improved from 13.09773 to 11.81499, saving model to Age_Sex_Detector.h5
# Epoch 15/250
# 278/278 [==============================] - ETA: 0s - loss: 7.7885 - sex-out_loss: 0.2927 - age-out_loss: 6.9906 - sex-out_accuracy: 0.8724 - age-out_accuracy: 0.0476
# Epoch 15: val_loss improved from 8.73549 to 8.45292, saving model to Age_Sex_Detector.h5
# 278/278 [==============================] - 40s 145ms/step - loss: 7.7885 - sex-out_loss: 0.2927 - age-out_loss: 6.9906 - sex-out_accuracy: 0.8724 - age-out_accuracy: 0.0476 - val_loss: 8.4529 - val_sex-out_loss: 0.2879 - val_age-out_loss: 7.6519 - val_sex-out_accuracy: 0.8701 - val_age-out_accuracy: 0.0466
# Epoch 16/250
# 278/278 [==============================] - ETA: 0s - loss: 7.6145 - sex-out_loss: 0.2885 - age-out_loss: 6.8051 - sex-out_accuracy: 0.8742 - age-out_accuracy: 0.0476
# Epoch 16: val_loss did not improve from 8.45292
# 278/278 [==============================] - 40s 146ms/step - loss: 7.6145 - sex-out_loss: 0.2885 - age-out_loss: 6.8051 - sex-out_accuracy: 0.8742 - age-out_accuracy: 0.0476 - val_loss: 8.8769 - val_sex-out_loss: 0.2910 - val_age-out_loss: 8.0575 - val_sex-out_accuracy: 0.8620 - val_age-out_accuracy: 0.0466
# Epoch 17/250
# 278/278 [==============================] - ETA: 0s - loss: 7.5059 - sex-out_loss: 0.2791 - age-out_loss: 6.6908 - sex-out_accuracy: 0.8746 - age-out_accuracy: 0.0476
# Epoch 17: val_loss did not improve from 8.45292
# 278/278 [==============================] - 41s 146ms/step - loss: 7.5059 - sex-out_loss: 0.2791 - age-out_loss: 6.6908 - sex-out_accuracy: 0.8746 - age-out_accuracy: 0.0476 - val_loss: 9.4218 - val_sex-out_loss: 0.2717 - val_age-out_loss: 8.6057 - val_sex-out_accuracy: 0.8757 - val_age-out_accuracy: 0.0466
# Epoch 18/250
# 278/278 [==============================] - ETA: 0s - loss: 7.3401 - sex-out_loss: 0.2761 - age-out_loss: 6.5108 - sex-out_accuracy: 0.8790 - age-out_accuracy: 0.0476
# Epoch 18: val_loss did not improve from 8.45292
# 278/278 [==============================] - 40s 146ms/step - loss: 7.3401 - sex-out_loss: 0.2761 - age-out_loss: 6.5108 - sex-out_accuracy: 0.8790 - age-out_accuracy: 0.0476 - val_loss: 9.1739 - val_sex-out_loss: 0.2669 - val_age-out_loss: 8.3465 - val_sex-out_accuracy: 0.8814 - val_age-out_accuracy: 0.0466
# Epoch 19/250
# 278/278 [==============================] - ETA: 0s - loss: 7.3206 - sex-out_loss: 0.2700 - age-out_loss: 6.4831 - sex-out_accuracy: 0.8821 - age-out_accuracy: 0.0476
# Epoch 19: val_loss improved from 8.45292 to 8.19806, saving model to Age_Sex_Detector.h5
# 278/278 [==============================] - 42s 152ms/step - loss: 7.3206 - sex-out_loss: 0.2700 - age-out_loss: 6.4831 - sex-out_accuracy: 0.8821 - age-out_accuracy: 0.0476 - val_loss: 8.1981 - val_sex-out_loss: 0.2674 - val_age-out_loss: 7.3565 - val_sex-out_accuracy: 0.8873 - val_age-out_accuracy: 0.0466
# Epoch 20/250
250
# 278/278 [==============================] - ETA: 0s - loss: 5.7050 - sex-out_loss: 0.1536 - age-out_loss: 4.4635 - sex-out_accuracy: 0.9374 - age-out_accuracy: 0.0438
# Epoch 107: val_loss did not improve from 7.40421
# 278/278 [==============================] - 41s 148ms/step - loss: 5.7050 - sex-out_loss: 0.1536 - age-out_loss: 4.4635 - sex-out_accuracy: 0.9374 - age-out_accuracy: 0.0438 - val_loss: 8.2734 - val_sex-out_loss: 0.2659 - val_age-out_loss: 6.9185 - val_sex-out_accuracy: 0.8886 - val_age-out_accuracy: 0.0466
# Epoch 108/250
# 278/278 [==============================] - ETA: 0s - loss: 5.7476 - sex-out_loss: 0.1585 - age-out_loss: 4.5000 - sex-out_accuracy: 0.9338 - age-out_accuracy: 0.0429
# Epoch 108: val_loss did not improve from 7.40421
# 278/278 [==============================] - 41s 146ms/step - loss: 5.7476 - sex-out_loss: 0.1585 - age-out_loss: 4.5000 - sex-out_accuracy: 0.9338 - age-out_accuracy: 0.0429 - val_loss: 8.2802 - val_sex-out_loss: 0.2639 - val_age-out_loss: 6.9261 - val_sex-out_accuracy: 0.9010 - val_age-out_accuracy: 0.0466
# Epoch 109/250
# 278/278 [==============================] - ETA: 0s - loss: 5.7294 - sex-out_loss: 0.1577 - age-out_loss: 4.4802 - sex-out_accuracy: 0.9364 - age-out_accuracy: 0.0433
# Epoch 109: val_loss did not improve from 7.40421
# 278/278 [==============================] - 40s 145ms/step - loss: 5.7294 - sex-out_loss: 0.1577 - age-out_loss: 4.4802 - sex-out_accuracy: 0.9364 - age-out_accuracy: 0.0433 - val_loss: 8.4632 - val_sex-out_loss: 0.2746 - val_age-out_loss: 7.0962 - val_sex-out_accuracy: 0.8988 - val_age-out_accuracy: 0.0466
# Epoch 110/250
# 278/278 [==============================] - ETA: 0s - loss: 5.7322 - sex-out_loss: 0.1553 - age-out_loss: 4.4839 - sex-out_accuracy: 0.9372 - age-out_accuracy: 0.0429
# Epoch 110: val_loss did not improve from 7.40421
# 278/278 [==============================] - 40s 145ms/step - loss: 5.7322 - sex-out_loss: 0.1553 - age-out_loss: 4.4839 - sex-out_accuracy: 0.9372 - age-out_accuracy: 0.0429 - val_loss: 7.8953 - val_sex-out_loss: 0.2662 - val_age-out_loss: 6.5348 - val_sex-out_accuracy: 0.8978 - val_age-out_accuracy: 0.0466
# Epoch 111/250
# 278/278 [==============================] - ETA: 0s - loss: 5.6941 - sex-out_loss: 0.1546 - age-out_loss: 4.4449 - sex-out_accuracy: 0.9365 - age-out_accuracy: 0.0435
# Epoch 111: val_loss did not improve from 7.40421
# 278/278 [==============================] - 43s 156ms/step - loss: 5.6941 - sex-out_loss: 0.1546 - age-out_loss: 4.4449 - sex-out_accuracy: 0.9365 - age-out_accuracy: 0.0435 - val_loss: 8.3312 - val_sex-out_loss: 0.2715 - val_age-out_loss: 6.9655 - val_sex-out_accuracy: 0.8944 - val_age-out_accuracy: 0.0466

# %% [markdown]
# ## Model Evaluation

# %%
Model.evaluate(X_test, Y_test_2)
# Out:
# 186/186 [==============================] - 3s 14ms/step - loss: 7.4042 - sex-out_loss: 0.2747 - age-out_loss: 6.3382 - sex-out_accuracy: 0.8881 - age-out_accuracy: 0.0466
# [7.404211521148682,
#  0.27474531531333923,
#  6.338156700134277,
#  0.888139009475708,
#  0.04656656086444855]

# %%
pred = Model.predict(X_test)
# Out:
# 186/186 [==============================] - 3s 12ms/step

# %%
pred[1]
# Out:
# array([[22.741016 ],
#        [ 6.1968617],
#        [36.9054   ],
#        ...,
#        [ 3.62939  ],
#        [25.438526 ],
#        [31.27021  ]], dtype=float32)

# %% [markdown]
# ## Plotting Loss

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.xlabel = ('Epoch')
plt.ylabel = ('Loss')
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.subplots_adjust(top = 1.0, bottom = 0.0, right = 0.95, left = 0, hspace = 0.25, wspace = 0.35)

# %% [markdown]
# ## Plotting Sex Accuracy

# %%
plt.plot(History.history['sex-out_accuracy'])
plt.plot(History.history['val_sex-out_accuracy'])
plt.title('Model Accuracy')
plt.xlabel = ('Epoch')
plt.ylabel = ('Accuracy')
plt.legend(['Train', 'Validation'], loc = 'upper left')
plt.subplots_adjust(top = 1.0, bottom = 0.0, right = 0.95, left = 0, hspace = 0.25, wspace = 0.35)

# %% [markdown]
# ## Plotting Age Accuracy

# %%
fig,ax = plt.subplots()
ax.scatter(Y_test_2[1], pred[1])
ax.plot([Y_test_2[1].min(), Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--',lw = 4)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age')
plt.show()

# %% [markdown]
# ## Making Report of the Model(Gender Only)

# %%
i = 0
Pred_l = []
while i < len(pred[0]):
    Pred_l.append(int(np.round(pred[0][i])))
    i += 1

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
report = classification_report(Y_test_2[0], Pred_l)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90      3129
#            1       0.91      0.84      0.88      2798
#
#     accuracy                           0.89      5927
#    macro avg       0.89      0.89      0.89      5927
# weighted avg       0.89      0.89      0.89      5927

# %% [markdown]
# ## Making HeatMap of the Model(Gender Only)

# %%
results = confusion_matrix(Y_test_2[0], Pred_l)

# %%
import seaborn as sns
sns.heatmap(results, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Testing the images by ourself

# %%
def test_image(ind, images_f, images_f_2, Model):
    plt.imshow(images_f[ind])
    image_test = images_f_2[ind]
    pred_l = Model.predict(np.array([image_test]))
    sex_f = ['Male', 'Female']
    age = int(np.round(pred_l[1][0]))
    sex = int(np.round(pred_l[0][0]))
    print("Predicted Age is " + str(age))
    print("Predicted Gender is " + sex_f[sex])

# %% [markdown]
# ## Test #1

# %%
test_image(4, images_f, images_f_2, Model)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Predicted Age is 94
# Predicted Gender is Female

# %% [markdown]
# ## Test #2

# %%
test_image(23, images_f, images_f_2, Model)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predicted Age is 8
# Predicted Gender is Male

# %% [markdown]
# ## Test #3

# %%
test_image(168, images_f, images_f_2, Model)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Predicted Age is 17
# Predicted Gender is Female

# %% [markdown]
# ## Test #4

# %%
test_image(888, images_f, images_f_2, Model)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Predicted Age is 18
# Predicted Gender is Male

# %% [markdown]
# ## Test #5

# %%
test_image(1288, images_f, images_f_2, Model)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Predicted Age is 26
# Predicted Gender is Female
